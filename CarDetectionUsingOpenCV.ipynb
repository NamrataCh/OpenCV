# %% [markdown]
# ### Car Detection Using OpenCV

# %%
import cv2
import numpy as np
import time

body_classifier=cv2.CascadeClassifier('Haarcascades/haarcascade_car.xml')
cap=cv2.VideoCapture('image_examples/cars.avi')

while cap.isOpened():
    
    time.sleep(.05)
    ret, frame=cap.read()
    
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    bodies=body_classifier.detectMultiScale(gray, 1.2, 3)
    
    for (x,y,w,h) in bodies:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,255), 2)
        cv2.imshow('Cars', frame)
        
        if cv2.waitKey(1)== 13 :# Presss enter to stop
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22636/4110286479.py in <module>
#       8 while cap.isOpened():
#       9
# ---> 10     time.sleep(.05)
#      11     ret, frame=cap.read()
#      12
#
# KeyboardInterrupt:

# %% [markdown]
# ![image.png](attachment:image.png)
